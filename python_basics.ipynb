# %% [markdown]
# <a href="https://colab.research.google.com/github/DanishHazim324/data-science-toolkit/blob/main/python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Welcome to data science')
# Out:
# Welcome to data science
